# %%
# %matplotlib inline
import pandas as pd
import pathlib

# %%
p = pathlib.Path(".","prueba.txt")
print(p)
Contacts\Archivos\m2000rt_275020965_190321-1_09212021_181920_R.txt
# Out:
# prueba.txt

# %%
arch=pd.read_csv("C:Archivos/m2000rt_275020965_010321-1_09212021_163656_R.txt",sep="\t",skiprows=19)
df=pd.DataFrame(arch)

# %%
df.head(50)
# Out:
#    UBICACIÓN DE LA MUESTRA ID DE MUESTRA TIPO DE MUESTRA NOMBRE DEL ENSAYO  \
# 0                       A1      10033399         Patient        SARS-COV-2
# 1                       A2      10033454         Patient        SARS-COV-2
# 2                       A3      10033434         Patient        SARS-COV-2
# 3                       A4      10033413         Patient        SARS-COV-2
# 4                       A5      10033404         Patient        SARS-COV-2
# 5                       A6      10033422         Patient        SARS-COV-2
# 6                       B1      10033400         Patient        SARS-COV-2
# 7                       B2      10033455         Patient        SARS-COV-2
# 8                       B3      10033435         Patient        SARS-COV-2
# 9                       B4      10033414         Patient        SARS-COV-2
# 10                      B5      10033407         Patient        SARS-COV-2
# ...

# %%
import glob

l = [pd.read_csv(filename) for filename in glob.glob("\Contacts\Archivos\*.txt")]
#df = pd.concat(l, axis=0)
